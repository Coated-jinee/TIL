# %% [markdown]
# ### R 프로그래밍 실습 특강 준비

# %% [markdown]
# 1일차 : R 프로그래밍 기초
# 이론 (1시간):
# - R의 기본 개념과 인터페이스 소개
# - R 설치 및 RStudio 환경 설정
# - 데이터 타입(숫자형, 문자형, 논리형)과 변수 선언
# - 기본 산술 연산, 벡터, 리스트, 행렬, 데이터 프레임 등 기본 자료 구조 소개
#
# 실습 (1시간):
# - R 설치
# - 워킹디렉토리 설정
# - 데이터 타입 실습 (숫자형, 문자형 등 선언 및 연산)
#
#
# 생물학 전공 친구들이 .. R을 배우면 .. 써먹을데가..?
# 통계 분석.. -> 사실 prism이 해주는데..
# single cell 분석할때 쓰고 ..
#
# 1. 데이터 분석 및 시각화
# 2. 통계적 가설 검정
# 3. 유전체 및 단백질체 분석
# 4. 클러스터링 및 차원 축소
# 5. 모델링과 예측
#
#
#
# 1.	Iris 데이터셋
# •	설명: 여러 종의 붓꽃 꽃잎과 꽃받침의 길이와 너비를 측정한 데이터로, 간단한 전처리와 분석에 적합합니다.
# •	활용 아이디어:
# •	전처리: 꽃잎 길이를 기준으로 특정 종만 필터링하거나, 꽃잎/꽃받침 길이의 평균을 계산
# •	통계 분석: 각 종별 꽃잎 길이의 평균을 비교하는 t-test, 꽃 종류와 꽃받침/꽃잎의 관계를 카이제곱 검정으로 확인
# •	시각화: 종별로 꽃잎과 꽃받침 길이의 분포를 시각화

# %% [markdown]
# ## R programming 특강 준비
# - 생명과학 전공 학부생, 졸업생 40명
# - R 아는지 모름
# - programming 기초 개념은 알까?
# - 통계에 대해 알까?
#
# 난이도 설정: 프로그래밍의 기초도 모른다 생각하고 설명. 생명과학 전공자를 위한 내용 포함..
# 학습 개요: 1일차 (프로그래밍 기본) 2일차(통계분석과 시각화 - 평균, 분산, 표준 편차, CLT ) 3일차(비지도학습: PCA와 t-SNE 시각화...)
#
#
# 1일차
#
# 개념편
# [] R
# [] 변수
# [] 연산자
# [] 데이터타입
# [] 제어문(반복문, 조건문)
# [] 함수
# [] 내장 함수
# [] 패키지
#
# 실습편
# [] R 설치하기
# [] R 실행하기
# [] Hello, world
# [] 주석
# [] 변수의 할당
# [] 기본 연산 연습
#
# 2일차
#
# 개념편
# [] 통계분석은 왜배울까
# [] 데이터셋 준비
# [] 통계분석을 위한 R 라이브러리 (ggplot, shiny)
# [] 정규분포
# [] 중심극한정리 (교수님이 설명할수도있으니까 일단 생략)
#
# [] PCA
# [] t-SNE
#
# 실습편
# [] 데이터 셋 불러오기
# [] 내장함수 - 평균, 표준편차
# [] 패키지 설치
# [] 시각화 (내장함수)
# [] ggplot으로 시각화
# []
#
# 3일차
# 이론편
# [] PCA
# [] t-SNE
#
# 실습편
# []
#
# - 이론+실습이 4시간인지 실습이 4시간인지?
#     - 이론 30분 실습자료 1시간으로 구성 - 실습시간 30분 줘야함.
# - 교수님이 이론 파트 맡으시는건지 마지막 날에 구현만 조금 한다는건지?
