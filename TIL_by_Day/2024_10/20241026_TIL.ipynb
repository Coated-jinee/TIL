# %% [markdown]
# # 2024년 10월 26일 토요일
# ## 할일
# - [x] 머신러닝 & 딥러닝 도전과제
#     - 영화 리뷰 감성 분석
#
# 도전 과제 가이드
# **주제**
# 영화 리뷰 데이터를 사용하여 긍정적/부정적 감정을 분류하는 모델을 만드는 프로젝트
#
# **목표**
# Netfilx의 영화 리뷰 데이터를 사용하여, 리뷰의 평점을 예측해보고, 긍정과 부정 감정을 분류해보는 것이 목표입니다. 과제는 순서대로 풀어주세요.
