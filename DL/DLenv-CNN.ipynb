# %% [markdown]
# CNN(합성곱 신경망)은 사람의 시각정보를 모델링함.
# ANN은 신경망을 모델링 - 추론 잘함
# CNN은 시각정보 - 이미지 처리 잘함. 이미지 특화

# %% [markdown]
# CNN은 왜 이미지 처리를 잘하나요?
# 이미지도 수치적으로 저장됨 (픽셀 값)
# CNN은 필터인데

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision
import torchvision.transforms as transforms

# %%
### 데이터셋 로드 및 전처리

# %%
# 데이터 셋 전처리
transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.5,), (0.5,))
])

# MNIST 데이터셋 로드
trainset = torchvision.datasets.MNIST(root='./data', train=True, download=True, transform=transform)
trainloader = torch.utils.data.DataLoader(trainset, batch_size=64, shuffle=True)

testset = torchvision.datasets.MNIST(root='./data', train=False, download=True, transform=transform)
testloader = torch.utils.data.DataLoader(testset, batch_size=64, shuffle=False)

# %%
class SimpleCNN(nn.Module):
    def __init__(self):
        super(SimpleCNN, self).__init__()
        self.conv1 = nn.Conv2d(1, 32, 3, padding=1)  # 입력 채널 1(흑백), 출력 채널 32, 커널 크기 3x3
        self.pool = nn.MaxPool2d(2, 2)               # 풀링 크기 2x2
        self.conv2 = nn.Conv2d(32, 64, 3, padding=1) # 입력 채널 32, 출력 채널 64, 커널 크기 3x3
        self.fc1 = nn.Linear(64 * 7 * 7, 512)        # 완전 연결 층
        self.fc2 = nn.Linear(512, 10)                # 출력 층 (10개의 클래스)

    def forward(self, x):
        x = self.pool(torch.relu(self.conv1(x))) #convolutional network 뒤에도 활성화 함수가 하나있어야함
        x = self.pool(torch.relu(self.conv2(x)))
        x = x.view(-1, 64 * 7 * 7)  # 플래튼 <- 2차원이나 3차원의 차원을 하나 펴줌
        x = torch.relu(self.fc1(x))
        x = self.fc2(x)
        return x

# %%
for i, (inputs, labels) in enumerate(trainloader, 0):
    print(inputs.shape)
# Out:
# torch.Size([64, 1, 28, 28])
# torch.Size([64, 1, 28, 28])
# torch.Size([64, 1, 28, 28])
# torch.Size([64, 1, 28, 28])
# torch.Size([64, 1, 28, 28])
# torch.Size([64, 1, 28, 28])
# torch.Size([64, 1, 28, 28])
# torch.Size([64, 1, 28, 28])
# torch.Size([64, 1, 28, 28])
# torch.Size([64, 1, 28, 28])
# torch.Size([64, 1, 28, 28])
# torch.Size([64, 1, 28, 28])
# torch.Size([64, 1, 28, 28])
# torch.Size([64, 1, 28, 28])
# torch.Size([64, 1, 28, 28])
# torch.Size([64, 1, 28, 28])
# torch.Size([64, 1, 28, 28])
# torch.Size([64, 1, 28, 28])
# torch.Size([64, 1, 28, 28])
# torch.Size([64, 1, 28, 28])
# torch.Size([64, 1, 28, 28])
# torch.Size([64, 1, 28, 28])
# torch.Size([64, 1, 28, 28])
# torch.Size([64, 1, 28, 28])
# torch.Size([64, 1, 28, 28])
# torch.Size([64, 1, 28, 28])
# torch.Size([64, 1, 28, 28])
# torch.Size([64, 1, 28, 28])
# torch.Size([64, 1, 28, 28])
# torch.Size([64, 1, 28, 28])
# torch.Size([64, 1, 28, 28])
# torch.Size([64, 1, 28, 28])
# torch.Size([64, 1, 28, 28])
# ...

# %%
# 모델 초기화
model = SimpleCNN()

# 손실 함수와 최적화 알고리즘 정의
criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(model.parameters(), lr=0.01, momentum=0.9)

# 모델 학습
for epoch in range(10):  # 10 에포크 동안 학습
    running_loss = 0.0
    for i, data in enumerate(trainloader, 0):
        inputs, labels = data

        # 기울기 초기화
        optimizer.zero_grad()

        # 순전파 + 역전파 + 최적화
        outputs = model(inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()

        # 손실 출력
        running_loss += loss.item()
        if i % 100 == 99:  # 매 100 미니배치마다 출력
            print(f'[Epoch {epoch + 1}, Batch {i + 1}] loss: {running_loss / 100:.3f}')
            running_loss = 0.0

print('Finished Training')
# Out:
# [Epoch 1, Batch 100] loss: 1.092
# [Epoch 1, Batch 200] loss: 0.235
# [Epoch 1, Batch 300] loss: 0.152
# [Epoch 1, Batch 400] loss: 0.121
# [Epoch 1, Batch 500] loss: 0.100
# [Epoch 1, Batch 600] loss: 0.084
# [Epoch 1, Batch 700] loss: 0.085
# [Epoch 1, Batch 800] loss: 0.077
# [Epoch 1, Batch 900] loss: 0.075
# [Epoch 2, Batch 100] loss: 0.057
# [Epoch 2, Batch 200] loss: 0.059
# [Epoch 2, Batch 300] loss: 0.050
# [Epoch 2, Batch 400] loss: 0.059
# [Epoch 2, Batch 500] loss: 0.045
# [Epoch 2, Batch 600] loss: 0.060
# [Epoch 2, Batch 700] loss: 0.046
# [Epoch 2, Batch 800] loss: 0.049
# [Epoch 2, Batch 900] loss: 0.042
# [Epoch 3, Batch 100] loss: 0.034
# [Epoch 3, Batch 200] loss: 0.042
# [Epoch 3, Batch 300] loss: 0.039
# [Epoch 3, Batch 400] loss: 0.034
# [Epoch 3, Batch 500] loss: 0.036
# [Epoch 3, Batch 600] loss: 0.033
# [Epoch 3, Batch 700] loss: 0.032
# [Epoch 3, Batch 800] loss: 0.036
# [Epoch 3, Batch 900] loss: 0.025
# [Epoch 4, Batch 100] loss: 0.026
# ...

# %%
correct = 0
total = 0
with torch.no_grad():
    for data in testloader:
        images, labels = data
        outputs = model(images)
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

print(f'Accuracy of the network on the 10000 test images: {100 * correct / total:.2f}%')
# Out:
# Accuracy of the network on the 10000 test images: 99.31%

# %% [markdown]
# 2. CIFAR-10

# %%
# 데이터셋 전처리
transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
])

# CIFAR-10 데이터셋 로드 (배, 비행기 처럼 class가 분류되어 있음)
#직접 해보는 거 추천. 아래에 답 코드 있음
# Out:
# ...
# 100.0%
# Extracting ./data/cifar-10-python.tar.gz to ./data
# Files already downloaded and verified

# %%
# 답

trainset = torchvision.datasets.CIFAR10(root='./data', train=True, download=True, transform=transform)
trainloader = torch.utils.data.DataLoader(trainset, batch_size=64, shuffle=True)

testset = torchvision.datasets.CIFAR10(root='./data', train=False, download=True, transform=transform)
testloader = torch.utils.data.DataLoader(testset, batch_size=64, shuffle=False)

# %%
class SimpleCNN(nn.Module):
    def __init__(self):
        super(SimpleCNN, self).__init__()
        self.conv1 = nn.Conv2d(3, 32, 3, padding=1)  # 입력 채널 3(RGB), 출력 채널 32, 커널 크기 3x3
        self.pool = nn.MaxPool2d(2, 2)               # 풀링 크기 2x2
        self.conv2 = nn.Conv2d(32, 64, 3, padding=1) # 입력 채널 32, 출력 채널 64, 커널 크기 3x3
        self.fc1 = nn.Linear(64 * 8 * 8, 512)        # 완전 연결 층
        self.fc2 = nn.Linear(512, 10)                # 출력 층 (10개의 클래스)

    def forward(self, x):
        x = self.pool(torch.relu(self.conv1(x))) #convolutional network 뒤에도 활성화 함수가 하나있어야함
        x = self.pool(torch.relu(self.conv2(x)))
        x = x.view(-1, 64 * 8 * 8)  # 플래튼 <- 2차원이나 3차원의 차원을 하나 펴줌
        x = torch.relu(self.fc1(x))
        x = self.fc2(x)
        return x
