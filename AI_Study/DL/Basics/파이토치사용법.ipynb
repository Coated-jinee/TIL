# %% [markdown]
# 1. 모델 구축 및 학습
# 기본 모델 구축
# 적절한 손실함수 골라쓰기
# 최적화 알고리즘 골라쓰기
#
# 2. 데이터 로드 및 전처리
# 데이터 셋 만들기 / 데이터 로더하기 (클래스 만들고, 데이터 로딩)
# 데이터 변환 유틸리티 고르기
# 3. GPU 설정 및 텐서 이동
# 모델을 GPU로 이동, 텐서를 GPU로 이동 - 이것 처럼 GPU 사용하게 설정하기
# 4. 모델 기법 별 API
# 합성곱 신경망
# 순한 신경망
# 트랜스포머
# 5. 유틸리티 함수
# 저장 및 로드
# - 모델 저장 (팁인게 중간단계 모델도 저장 해라. 쓸일이 있다.)
# - 모델 로드
# 학습 및 평가 모드 설정
# - 모델을 학습 모드로 설정
# - 모델을 평가 모드로 설정
#
# 사실적으로 딥러닝 모델은 개인의 역량으로 해결하는 건 많이 줄어들긴했음. 모델이 커졌음
# fine 튜닝하고, 적합한 모델 찾는걸 많이 해야함
